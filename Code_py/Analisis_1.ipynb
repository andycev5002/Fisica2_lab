# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_excel("C:/Users/andy\Desktop/6to_semestre/Fisica/Lab/Codigo/Fisica2_lab/Code_py/LAB1.xlsx")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\andy\AppData\Local\Temp\ipykernel_18080\663123186.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_excel("C:/Users/andy\Desktop/6to_semestre/Fisica/Lab/Codigo/Fisica2_lab/Code_py/LAB1.xlsx")

# %%
df
# Out:
#             Column1 Column2 Column3   Column4    Column6 Column7  Unnamed: 6  \
# 0              60Hz    Pico   P a P         T  Vcd Media    Vrms         NaN
# 1          Reticula    2x2      4x2       160      0.099   2.086         NaN
# 2          Cursores  3.84 V     8 V       NaN        NaN     NaN         NaN
# 3      Autom[aticas      4V   7.92V  166.0 us        NaN   2.77v         NaN
# 4        Triangular   4.00v    8.2v   17.2 ms     -0.033    2.29         NaN
# 5          Cuadrada     4.8   8.24V   166.4us     -0.037   2.802         NaN
# 6     Sinoidal 60Hz   3.20V   6.52v  176.8 ms     1.973V  3.256V         NaN
# 7   Sinoidal 600 HZ   2.86v     10v   1.550US     0.139v  3.300v         NaN
# 8  Sinoidal 6000 HZ   5.00v   10.1v  166.8.us    0.132 V  2.559V         NaN
#
#     Unnamed: 7  Unnamed: 8 Unnamed: 9
# 0          NaN         NaN        NaN
# 1    M= 100 us         NaN        NaN
# 2        2.00V         NaN     0.01 V
# 3  \pm 0.1 (V)         NaN        NaN
# 4   0.001(V ~)         NaN        NaN
# 5   0.001 (V)-         NaN        NaN
# 6          NaN         NaN        NaN
# 7          NaN         NaN        NaN
# 8          NaN         NaN        NaN

# %%
Pico = df["Column2"].to_numpy

# %%
x
# Out:
# <bound method IndexOpsMixin.to_numpy of 0      Pico
# 1      2x2
# 2    3.84 V
# 3        4V
# 4     4.00v
# 5       4.8
# 6     3.20V
# 7     2.86v
# 8     5.00v
# Name: Column2, dtype: object>
